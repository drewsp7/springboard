# %% [markdown]
# # JSON examples and exercise
# ****
# + get familiar with packages for dealing with JSON
# + study examples with JSON strings and files
# + work on exercise to be completed and submitted
# ****
# + reference: http://pandas.pydata.org/pandas-docs/stable/io.html#io-json-reader
# + data source: http://jsonstudio.com/resources/
# ****

# %%
import pandas as pd

# %% [markdown]
# ## imports for Python, Pandas

# %%
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## JSON example, with string
#
# + demonstrates creation of normalized dataframes (tables) from nested json string
# + source: http://pandas.pydata.org/pandas-docs/stable/io.html#normalization

# %%
# define json string
data = [{'state': 'Florida', 
         'shortname': 'FL',
         'info': {'governor': 'Rick Scott'},
         'counties': [{'name': 'Dade', 'population': 12345},
                      {'name': 'Broward', 'population': 40000},
                      {'name': 'Palm Beach', 'population': 60000}]},
        {'state': 'Ohio',
         'shortname': 'OH',
         'info': {'governor': 'John Kasich'},
         'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
# use normalization to create tables from nested element
json_normalize(data, 'counties')
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
# further populate tables created from nested element
json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %% [markdown]
# ****
# ## JSON example, with file
#
# + demonstrates reading in a json file as a string and as a table
# + uses small sample file containing data about projects funded by the World Bank
# + data source: http://jsonstudio.com/resources/

# %%
# load json as string
json.load((open('data/world_bank_projects_less.json')))
# Out:
# [{'_id': {'$oid': '52b213b38594d8a2be17c780'},
#   'approvalfy': 1999,
#   'board_approval_month': 'November',
#   'boardapprovaldate': '2013-11-12T00:00:00Z',
#   'borrower': 'FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA',
#   'closingdate': '2018-07-07T00:00:00Z',
#   'country_namecode': 'Federal Democratic Republic of Ethiopia!$!ET',
#   'countrycode': 'ET',
#   'countryname': 'Federal Democratic Republic of Ethiopia',
#   'countryshortname': 'Ethiopia',
#   'docty': 'Project Information Document,Indigenous Peoples Plan,Project Information Document',
#   'envassesmentcategorycode': 'C',
#   'grantamt': 0,
#   'ibrdcommamt': 0,
#   'id': 'P129828',
#   'idacommamt': 130000000,
#   'impagency': 'MINISTRY OF EDUCATION',
#   'lendinginstr': 'Investment Project Financing',
#   'lendinginstrtype': 'IN',
#   'lendprojectcost': 550000000,
#   'majorsector_percent': [{'Name': 'Education', 'Percent': 46},
#    {'Name': 'Education', 'Percent': 26},
#    {'Name': 'Public Administration, Law, and Justice', 'Percent': 16},
#    {'Name': 'Education', 'Percent': 12}],
#   'mjsector_namecode': [{'code': 'EX', 'name': 'Education'},
#    {'code': 'EX', 'name': 'Education'},
#    {'code': 'BX', 'name': 'Public Administration, Law, and Justice'},
#    {'code': 'EX', 'name': 'Education'}],
#   'mjtheme': ['Human development'],
#   'mjtheme_namecode': [{'code': '8', 'name': 'Human development'},
#    {'code': '11', 'name': ''}],
#   'mjthemecode': '8,11',
#   'prodline': 'PE',
#   'prodlinetext': 'IBRD/IDA',
#   'productlinetype': 'L',
#   'project_abstract': {'cdata': 'The development objective of the Second Phase of General Education Quality Improvement Project for Ethiopia is to improve learning conditions in primary and secondary schools and strengthen institutions at different levels of educational administration. The project has six components. The first component is curriculum, textbooks, assessment, examinations, and inspection. This component will support improvement of learning conditions in grades KG-12 by providing increased access to teaching and learning materials and through improvements to the curriculum by assessing the strengths and weaknesses of the current curriculum. This component has following four sub-components: (i) curriculum reform and implementation; (ii) teaching and learning materials; (iii) assessment and examinations; and (iv) inspection. The second component is teacher development program (TDP). This component will support improvements in learning conditions in both primary and secondary schools by advancing the quality of teaching in general education through: (a) enhancing the training of pre-service teachers in teacher education institutions; and (b) improving the quality of in-service teacher training. This component has following three sub-components: (i) pre-service teacher training; (ii) in-service teacher training; and (iii) licensing and relicensing of teachers and school leaders. The third component is school improvement plan. This component will support the strengthening of school planning in order to improve learning outcomes, and to partly fund the school improvement plans through school grants. It has following two sub-components: (i) school improvement plan; and (ii) school grants. The fourth component is management and capacity building, including education management information systems (EMIS). This component will support management and capacity building aspect of the project. This component has following three sub-components: (i) capacity building for education planning and management; (ii) capacity building for school planning and management; and (iii) EMIS. The fifth component is improving the quality of learning and teaching in secondary schools and universities through the use of information and communications technology (ICT). It has following five sub-components: (i) national policy and institution for ICT in general education; (ii) national ICT infrastructure improvement plan for general education; (iii) develop an integrated monitoring, evaluation, and learning system specifically for the ICT component; (iv) teacher professional development in the use of ICT; and (v) provision of limited number of e-Braille display readers with the possibility to scale up to all secondary education schools based on the successful implementation and usage of the readers. The sixth component is program coordination, monitoring and evaluation, and communication. It will support institutional strengthening by developing capacities in all aspects of program coordination, monitoring and evaluation; a new sub-component on communications will support information sharing for better management and accountability. It has following three sub-components: (i) program coordination; (ii) monitoring and evaluation (M and E); and (iii) communication.'},
#   'project_name': 'Ethiopia General Education Quality Improvement Project II',
#   'projectdocs': [{'DocDate': '28-AUG-2013',
#     'DocType': 'PID',
#     'DocTypeDesc': 'Project Information Document (PID),  Vol.',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=090224b081e545fb_1_0',
#     'EntityID': '090224b081e545fb_1_0'},
#    {'DocDate': '01-JUL-2013',
#     'DocType': 'IP',
#     'DocTypeDesc': 'Indigenous Peoples Plan (IP),  Vol.1 of 1',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000442464_20130920111729',
#     'EntityID': '000442464_20130920111729'},
#    {'DocDate': '22-NOV-2012',
#     'DocType': 'PID',
#     'DocTypeDesc': 'Project Information Document (PID),  Vol.',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=090224b0817b19e2_1_0',
#     'EntityID': '090224b0817b19e2_1_0'}],
#   'projectfinancialtype': 'IDA',
#   'projectstatusdisplay': 'Active',
#   'regionname': 'Africa',
#   'sector': [{'Name': 'Primary education'},
#    {'Name': 'Secondary education'},
#    {'Name': 'Public administration- Other social services'},
#    {'Name': 'Tertiary education'}],
#   'sector1': {'Name': 'Primary education', 'Percent': 46},
#   'sector2': {'Name': 'Secondary education', 'Percent': 26},
#   'sector3': {'Name': 'Public administration- Other social services',
#    'Percent': 16},
#   'sector4': {'Name': 'Tertiary education', 'Percent': 12},
#   'sector_namecode': [{'code': 'EP', 'name': 'Primary education'},
#    {'code': 'ES', 'name': 'Secondary education'},
#    {'code': 'BS', 'name': 'Public administration- Other social services'},
#    {'code': 'ET', 'name': 'Tertiary education'}],
#   'sectorcode': 'ET,BS,ES,EP',
#   'source': 'IBRD',
#   'status': 'Active',
#   'supplementprojectflg': 'N',
#   'theme1': {'Name': 'Education for all', 'Percent': 100},
#   'theme_namecode': [{'code': '65', 'name': 'Education for all'}],
#   'themecode': '65',
#   'totalamt': 130000000,
#   'totalcommamt': 130000000,
#   'url': 'http://www.worldbank.org/projects/P129828/ethiopia-general-education-quality-improvement-project-ii?lang=en'},
#  {'_id': {'$oid': '52b213b38594d8a2be17c781'},
#   'approvalfy': 2015,
#   'board_approval_month': 'November',
#   'boardapprovaldate': '2013-11-04T00:00:00Z',
#   'borrower': 'GOVERNMENT OF TUNISIA',
#   'country_namecode': 'Republic of Tunisia!$!TN',
#   'countrycode': 'TN',
#   'countryname': 'Republic of Tunisia',
#   'countryshortname': 'Tunisia',
#   'docty': 'Project Information Document,Integrated Safeguards Data Sheet,Integrated Safeguards Data Sheet,Project Information Document,Integrated Safeguards Data Sheet,Project Information Document',
#   'envassesmentcategorycode': 'C',
#   'grantamt': 4700000,
#   'ibrdcommamt': 0,
#   'id': 'P144674',
#   'idacommamt': 0,
#   'impagency': 'MINISTRY OF FINANCE',
#   'lendinginstr': 'Specific Investment Loan',
#   'lendinginstrtype': 'IN',
#   'lendprojectcost': 5700000,
#   'majorsector_percent': [{'Name': 'Public Administration, Law, and Justice',
#     'Percent': 70},
#    {'Name': 'Public Administration, Law, and Justice', 'Percent': 30}],
#   'mjsector_namecode': [{'code': 'BX',
#     'name': 'Public Administration, Law, and Justice'},
#    {'code': 'BX', 'name': 'Public Administration, Law, and Justice'}],
#   'mjtheme': ['Economic management', 'Social protection and risk management'],
#   'mjtheme_namecode': [{'code': '1', 'name': 'Economic management'},
#    {'code': '6', 'name': 'Social protection and risk management'}],
#   'mjthemecode': '1,6',
#   'prodline': 'RE',
#   'prodlinetext': 'Recipient Executed Activities',
#   'productlinetype': 'L',
#   'project_name': 'TN: DTF Social Protection Reforms Support',
#   'projectdocs': [{'DocDate': '29-MAR-2013',
#     'DocType': 'PID',
#     'DocTypeDesc': 'Project Information Document (PID),  Vol.1 of 1',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000333037_20131024115616',
#     'EntityID': '000333037_20131024115616'},
#    {'DocDate': '29-MAR-2013',
#     'DocType': 'ISDS',
#     'DocTypeDesc': 'Integrated Safeguards Data Sheet (ISDS),  Vol.1 of 1',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000356161_20131024151611',
#     'EntityID': '000356161_20131024151611'},
#    {'DocDate': '29-MAR-2013',
#     'DocType': 'ISDS',
#     'DocTypeDesc': 'Integrated Safeguards Data Sheet (ISDS),  Vol.1 of 1',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000442464_20131031112136',
#     'EntityID': '000442464_20131031112136'},
#    {'DocDate': '29-MAR-2013',
#     'DocType': 'PID',
#     'DocTypeDesc': 'Project Information Document (PID),  Vol.1 of 1',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000333037_20131031105716',
#     'EntityID': '000333037_20131031105716'},
#    {'DocDate': '16-JAN-2013',
#     'DocType': 'ISDS',
#     'DocTypeDesc': 'Integrated Safeguards Data Sheet (ISDS),  Vol.1 of 1',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000356161_20130305113209',
#     'EntityID': '000356161_20130305113209'},
#    {'DocDate': '16-JAN-2013',
#     'DocType': 'PID',
#     'DocTypeDesc': 'Project Information Document (PID),  Vol.1 of 1',
#     'DocURL': 'http://www-wds.worldbank.org/servlet/WDSServlet?pcont=details&eid=000356161_20130305113716',
#     'EntityID': '000356161_20130305113716'}],
#   'projectfinancialtype': 'OTHER',
#   'projectstatusdisplay': 'Active',
#   'regionname': 'Middle East and North Africa',
#   'sector': [{'Name': 'Public administration- Other social services'},
#    {'Name': 'General public administration sector'}],
#   'sector1': {'Name': 'Public administration- Other social services',
#    'Percent': 70},
#   'sector2': {'Name': 'General public administration sector', 'Percent': 30},
#   'sector_namecode': [{'code': 'BS',
#     'name': 'Public administration- Other social services'},
#    {'code': 'BZ', 'name': 'General public administration sector'}],
#   'sectorcode': 'BZ,BS',
#   'source': 'IBRD',
#   'status': 'Active',
#   'supplementprojectflg': 'N',
#   'theme1': {'Name': 'Other economic management', 'Percent': 30},
#   'theme_namecode': [{'code': '24', 'name': 'Other economic management'},
#    {'code': '54', 'name': 'Social safety nets'}],
#   'themecode': '54,24',
#   'totalamt': 0,
#   'totalcommamt': 4700000,
#   'url': 'http://www.worldbank.org/projects/P144674?lang=en'}]

# %%
# load as Pandas dataframe
sample_json_df = pd.read_json('data/world_bank_projects_less.json')
sample_json_df
#print(type(sample_json_df))
# Out:
#                                     _id  approvalfy board_approval_month  \
# 0  {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1  {'$oid': '52b213b38594d8a2be17c781'}        2015             November
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
#
#             closingdate                              country_namecode  \
# 0  2018-07-07T00:00:00Z  Federal Democratic Republic of Ethiopia!$!ET
# 1                   NaN                      Republic of Tunisia!$!TN
#
#   countrycode                              countryname countryshortname  \
# 0          ET  Federal Democratic Republic of Ethiopia         Ethiopia
# 1          TN                      Republic of Tunisia          Tunisia
#
#                          ...                           sectorcode source  \
# 0                        ...                          ET,BS,ES,EP   IBRD
# 1                        ...                                BZ,BS   IBRD
#
#    status  supplementprojectflg  \
# 0  Active                     N
# 1  Active                     N
#
#                                               theme1  \
# 0      {'Name': 'Education for all', 'Percent': 100}
# 1  {'Name': 'Other economic management', 'Percent...
#
#                                       theme_namecode themecode   totalamt  \
# 0      [{'name': 'Education for all', 'code': '65'}]        65  130000000
# 1  [{'name': 'Other economic management', 'code':...     54,24          0
#
#   totalcommamt                                                url
# 0    130000000  http://www.worldbank.org/projects/P129828/ethi...
# 1      4700000  http://www.worldbank.org/projects/P144674?lang=en
#
# [2 rows x 50 columns]

# %% [markdown]
# ****
# ## JSON exercise
#
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.
#
# ## Problem #1: Find the 10 countries with the most projects

# %%
#load as pandas dataframe
df = pd.read_json('data/world_bank_projects.json')
  #pandas.core.frame.DataFrame - shows this json is a pandas dataFrame and not dict

# %%
#Let's do some index searching to make sure we can explore..hmmmm looks like a dictionary, but its not!
#https://dsintensivecommunity.springboard.com/t/m2tm03/unit-3-3-json-exercise-n3-lookup-table
df['_id'][3]
with open('data/world_bank_projects.json') as f:
    raw = json.load(f)

# %%
#Use describe to look at the interesting details
df.countrycode.describe()
# Out:
# count     500
# unique    118
# top        CN
# freq       19
# Name: countrycode, dtype: object

# %% [markdown]
# #### Interesting, there are 500 rows, but only 118 unique countries

# %%
# Let's use groupby to aggregate the count of each country. First, extract the 'countryname' column from the DataFrame.
by_country = df.groupby('countryname')
#Next, aggregate 'countryname' and count the totals. This will not place it in sorted order.
count_by_country = by_country['countryname'].count()
#Finally, sort so can see the totals by country. 
count_by_country.sort_values(ascending=False).head(10)
#to reuse the output, can assign to a variable to select only the top 10. 
#Note: To see all of the countries, remove .head(10) and run the below line:
#print(count_by_country.sort_values(ascending=False))
# Out:
# countryname
# People's Republic of China         19
# Republic of Indonesia              19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# Nepal                              12
# People's Republic of Bangladesh    12
# Kingdom of Morocco                 12
# Africa                             11
# Republic of Mozambique             11
# Name: countryname, dtype: int64

# %% [markdown]
# # Answer: above are the top 10 countries with the most projects
#
# # Question 2.Find the top 10 major project themes (using column 'mjtheme_namecode')

# %%
#Find the column names. 
df.columns
# Out:
# Index(['_id', 'approvalfy', 'board_approval_month', 'boardapprovaldate',
#        'borrower', 'closingdate', 'country_namecode', 'countrycode',
#        'countryname', 'countryshortname', 'docty', 'envassesmentcategorycode',
#        'grantamt', 'ibrdcommamt', 'id', 'idacommamt', 'impagency',
#        'lendinginstr', 'lendinginstrtype', 'lendprojectcost',
#        'majorsector_percent', 'mjsector_namecode', 'mjtheme',
#        'mjtheme_namecode', 'mjthemecode', 'prodline', 'prodlinetext',
#        'productlinetype', 'project_abstract', 'project_name', 'projectdocs',
#        'projectfinancialtype', 'projectstatusdisplay', 'regionname', 'sector',
#        'sector1', 'sector2', 'sector3', 'sector4', 'sector_namecode',
#        'sectorcode', 'source', 'status', 'supplementprojectflg', 'theme1',
#        'theme_namecode', 'themecode', 'totalamt', 'totalcommamt', 'url'],
#       dtype='object')

# %%
print(df['mjtheme_namecode'])
# Out:
# 0      [{'code': '8', 'name': 'Human development'}, {...
# 1      [{'code': '1', 'name': 'Economic management'},...
# 2      [{'code': '5', 'name': 'Trade and integration'...
# 3      [{'code': '7', 'name': 'Social dev/gender/incl...
# 4      [{'code': '5', 'name': 'Trade and integration'...
# 5      [{'code': '6', 'name': 'Social protection and ...
# 6      [{'code': '2', 'name': 'Public sector governan...
# 7      [{'code': '11', 'name': 'Environment and natur...
# 8      [{'code': '10', 'name': 'Rural development'}, ...
# 9      [{'code': '2', 'name': 'Public sector governan...
# 10     [{'code': '10', 'name': 'Rural development'}, ...
# 11     [{'code': '10', 'name': 'Rural development'}, ...
# 12     [{'code': '4', 'name': 'Financial and private ...
# 13     [{'code': '5', 'name': 'Trade and integration'...
# 14     [{'code': '6', 'name': 'Social protection and ...
# 15     [{'code': '10', 'name': 'Rural development'}, ...
# 16     [{'code': '10', 'name': 'Rural development'}, ...
# 17     [{'code': '8', 'name': 'Human development'}, {...
# 18     [{'code': '8', 'name': 'Human development'}, {...
# 19     [{'code': '2', 'name': 'Public sector governan...
# 20     [{'code': '7', 'name': 'Social dev/gender/incl...
# 21     [{'code': '9', 'name': 'Urban development'}, {...
# 22     [{'code': '7', 'name': 'Social dev/gender/incl...
# 23     [{'code': '8', 'name': 'Human development'}, {...
# 24     [{'code': '10', 'name': 'Rural development'}, ...
# 25     [{'code': '11', 'name': 'Environment and natur...
# 26     [{'code': '4', 'name': 'Financial and private ...
# 27     [{'code': '11', 'name': 'Environment and natur...
# 28     [{'code': '10', 'name': 'Rural development'}, ...
# 29     [{'code': '7', 'name': 'Social dev/gender/incl...
#                              ...
# 470    [{'code': '5', 'name': 'Trade and integration'...
# 471    [{'code': '10', 'name': 'Rural development'}, ...
# 472    [{'code': '11', 'name': 'Environment and natur...
# 473    [{'code': '11', 'name': 'Environment and natur...
# 474    [{'code': '9', 'name': 'Urban development'}, {...
# 475    [{'code': '4', 'name': 'Financial and private ...
# 476    [{'code': '10', 'name': 'Rural development'}, ...
# 477    [{'code': '4', 'name': 'Financial and private ...
# 478    [{'code': '2', 'name': 'Public sector governan...
# 479    [{'code': '7', 'name': 'Social dev/gender/incl...
# 480    [{'code': '2', 'name': 'Public sector governan...
# 481    [{'code': '8', 'name': 'Human development'}, {...
# 482    [{'code': '10', 'name': 'Rural development'}, ...
# 483    [{'code': '11', 'name': 'Environment and natur...
# 484    [{'code': '10', 'name': 'Rural development'}, ...
# 485    [{'code': '8', 'name': 'Human development'}, {...
# 486    [{'code': '2', 'name': 'Public sector governan...
# 487    [{'code': '11', 'name': 'Environment and natur...
# 488    [{'code': '8', 'name': 'Human development'}, {...
# 489    [{'code': '9', 'name': 'Urban development'}, {...
# 490    [{'code': '2', 'name': 'Public sector governan...
# 491    [{'code': '10', 'name': 'Rural development'}, ...
# 492    [{'code': '8', 'name': 'Human development'}, {...
# 493    [{'code': '11', 'name': 'Environment and natur...
# 494    [{'code': '6', 'name': 'Social protection and ...
# 495    [{'code': '4', 'name': 'Financial and private ...
# 496    [{'code': '8', 'name': 'Human development'}, {...
# 497    [{'code': '10', 'name': 'Rural development'}, ...
# 498    [{'code': '10', 'name': 'Rural development'}, ...
# 499    [{'code': '9', 'name': 'Urban development'}, {...
# Name: mjtheme_namecode, dtype: object

# %%
#test - cycle through and print the key value pairs. The index integer is the key and list of lists is the value
major_theme = df['mjtheme_namecode']
for k,v in major_theme.items():
    print(k,":\"<-key\" ",v)
print(type(major_theme)) #pandas series
# Out:
# 0 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]
# 1 :"<-key"  [{'code': '1', 'name': 'Economic management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 2 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 3 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 4 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 5 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': ''}]
# 6 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 7 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '8', 'name': ''}]
# 8 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': ''}]
# 9 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 10 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '2', 'name': ''}]
# 11 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 12 :"<-key"  [{'code': '4', 'name': ''}]
# 13 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}]
# 14 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 15 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '5', 'name': 'Trade and integration'}]
# 16 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '2', 'name': ''}]
# 17 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '7', 'name': ''}]
# 18 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}]
# 19 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 20 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 21 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 22 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 23 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 24 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 25 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 26 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}]
# 27 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 28 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 29 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 30 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '4', 'name': ''}]
# 31 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 32 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 33 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '1', 'name': 'Economic management'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 34 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '5', 'name': 'Trade and integration'}]
# 35 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 36 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': ''}]
# 37 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '7', 'name': ''}]
# 38 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 39 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': ''}]
# 40 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 41 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '8', 'name': 'Human development'}]
# 42 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 43 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': ''}]
# 44 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '7', 'name': ''}]
# 45 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '10', 'name': ''}]
# 46 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': 'Rural development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 47 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': ''}]
# 48 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 49 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}]
# 50 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': ''}]
# 51 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 52 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 53 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}]
# 54 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 55 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 56 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 57 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 58 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 59 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 60 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': ''}]
# 61 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 62 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': ''}]
# 63 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': ''}]
# 64 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '1', 'name': 'Economic management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '2', 'name': 'Public sector governance'}]
# 65 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}, {'code': '5', 'name': 'Trade and integration'}]
# 66 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 67 :"<-key"  [{'code': '7', 'name': ''}]
# 68 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]
# 69 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 70 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 71 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '9', 'name': 'Urban development'}, {'code': '10', 'name': 'Rural development'}]
# 72 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': ''}]
# 73 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 74 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '5', 'name': ''}]
# 75 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '1', 'name': 'Economic management'}, {'code': '1', 'name': 'Economic management'}, {'code': '8', 'name': 'Human development'}]
# 76 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 77 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': ''}]
# 78 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '1', 'name': ''}]
# 79 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 80 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': ''}]
# 81 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '1', 'name': 'Economic management'}]
# 82 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '1', 'name': 'Economic management'}]
# 83 :"<-key"  [{'code': '1', 'name': 'Economic management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 84 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}]
# 85 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '4', 'name': ''}]
# 86 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': ''}]
# 87 :"<-key"  [{'code': '11', 'name': ''}]
# 88 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': ''}]
# 89 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 90 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': ''}]
# 91 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '11', 'name': ''}]
# 92 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 93 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 94 :"<-key"  [{'code': '1', 'name': 'Economic management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 95 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '3', 'name': 'Rule of law'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 96 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 97 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 98 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}]
# 99 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': 'Rural development'}]
# 100 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 101 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': ''}]
# 102 :"<-key"  [{'code': '2', 'name': ''}]
# 103 :"<-key"  [{'code': '11', 'name': ''}]
# 104 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 105 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 106 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}]
# 107 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 108 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 109 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': ''}]
# 110 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}]
# 111 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}, {'code': '2', 'name': 'Public sector governance'}]
# 112 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 113 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': 'Rural development'}, {'code': '8', 'name': 'Human development'}]
# 114 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}]
# 115 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '9', 'name': 'Urban development'}]
# 116 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 117 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 118 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 119 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 120 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': ''}]
# 121 :"<-key"  [{'code': '9', 'name': ''}]
# 122 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 123 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '2', 'name': 'Public sector governance'}]
# 124 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '9', 'name': 'Urban development'}]
# 125 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}]
# 126 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '10', 'name': 'Rural development'}]
# 127 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 128 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': 'Rural development'}, {'code': '9', 'name': 'Urban development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '9', 'name': 'Urban development'}]
# 129 :"<-key"  [{'code': '1', 'name': 'Economic management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '3', 'name': 'Rule of law'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 130 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '1', 'name': ''}]
# 131 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '7', 'name': ''}]
# 132 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '9', 'name': 'Urban development'}]
# 133 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 134 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 135 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 136 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 137 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 138 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': ''}]
# 139 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': ''}]
# 140 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}]
# 141 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': 'Public sector governance'}]
# 142 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 143 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': ''}]
# 144 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '11', 'name': ''}]
# 145 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 146 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '8', 'name': 'Human development'}, {'code': '9', 'name': 'Urban development'}]
# 147 :"<-key"  [{'code': '3', 'name': 'Rule of law'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 148 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 149 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': ''}]
# 150 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 151 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}]
# 152 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '8', 'name': ''}]
# 153 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': ''}]
# 154 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 155 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}]
# 156 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': ''}]
# 157 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 158 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '1', 'name': 'Economic management'}]
# 159 :"<-key"  [{'code': '1', 'name': 'Economic management'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': 'Rural development'}, {'code': '1', 'name': 'Economic management'}]
# 160 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '9', 'name': ''}]
# 161 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '2', 'name': ''}]
# 162 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 163 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 164 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '9', 'name': ''}]
# 165 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 166 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 167 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}]
# 168 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 169 :"<-key"  [{'code': '2', 'name': ''}]
# 170 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 171 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}, {'code': '2', 'name': 'Public sector governance'}]
# 172 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '3', 'name': ''}]
# 173 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '1', 'name': 'Economic management'}]
# 174 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 175 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 176 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '3', 'name': 'Rule of law'}, {'code': '3', 'name': 'Rule of law'}]
# 177 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '9', 'name': 'Urban development'}, {'code': '9', 'name': 'Urban development'}]
# 178 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 179 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 180 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': 'Human development'}]
# 181 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 182 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 183 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '4', 'name': ''}]
# 184 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '9', 'name': 'Urban development'}, {'code': '8', 'name': 'Human development'}]
# 185 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': 'Human development'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 186 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 187 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}, {'code': '10', 'name': 'Rural development'}, {'code': '8', 'name': 'Human development'}]
# 188 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': 'Human development'}]
# 189 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 190 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 191 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}]
# 192 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]
# 193 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 194 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 195 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '2', 'name': 'Public sector governance'}]
# 196 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': 'Rural development'}, {'code': '8', 'name': 'Human development'}]
# 197 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 198 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '2', 'name': 'Public sector governance'}]
# 199 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}]
# 200 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '9', 'name': 'Urban development'}]
# 201 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 202 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '2', 'name': ''}]
# 203 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 204 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 205 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '9', 'name': 'Urban development'}]
# 206 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '5', 'name': 'Trade and integration'}]
# 207 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}]
# 208 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 209 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': ''}]
# 210 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 211 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': 'Human development'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 212 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}]
# 213 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}]
# 214 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 215 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': 'Human development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 216 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 217 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 218 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 219 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': 'Rural development'}]
# 220 :"<-key"  [{'code': '1', 'name': 'Economic management'}, {'code': '1', 'name': 'Economic management'}, {'code': '2', 'name': 'Public sector governance'}]
# 221 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 222 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}]
# 223 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 224 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': 'Public sector governance'}]
# 225 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 226 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': ''}]
# 227 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '2', 'name': 'Public sector governance'}]
# 228 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 229 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 230 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 231 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': ''}]
# 232 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': ''}]
# 233 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]
# 234 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '7', 'name': ''}]
# 235 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': ''}]
# 236 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 237 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '3', 'name': ''}]
# 238 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '8', 'name': 'Human development'}]
# 239 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': ''}]
# 240 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 241 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]
# 242 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}, {'code': '10', 'name': 'Rural development'}]
# 243 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 244 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}, {'code': '8', 'name': 'Human development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 245 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 246 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 247 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 248 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 249 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 250 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 251 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 252 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '9', 'name': 'Urban development'}]
# 253 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '9', 'name': 'Urban development'}]
# 254 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '10', 'name': 'Rural development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 255 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 256 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 257 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 258 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 259 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 260 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 261 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 262 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 263 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 264 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 265 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '1', 'name': 'Economic management'}, {'code': '2', 'name': 'Public sector governance'}]
# 266 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '3', 'name': 'Rule of law'}, {'code': '10', 'name': 'Rural development'}]
# 267 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 268 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 269 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 270 :"<-key"  [{'code': '1', 'name': 'Economic management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '2', 'name': 'Public sector governance'}]
# 271 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 272 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 273 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '10', 'name': 'Rural development'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 274 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': 'Rural development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}]
# 275 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 276 :"<-key"  [{'code': '10', 'name': ''}]
# ...
# 405 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '1', 'name': 'Economic management'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': 'Public sector governance'}]
# 406 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 407 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '6', 'name': ''}]
# 408 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 409 :"<-key"  [{'code': '1', 'name': 'Economic management'}, {'code': '1', 'name': 'Economic management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 410 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '1', 'name': 'Economic management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 411 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': ''}]
# 412 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': ''}]
# 413 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': ''}]
# 414 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': ''}]
# 415 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 416 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 417 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '8', 'name': 'Human development'}]
# 418 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 419 :"<-key"  [{'code': '1', 'name': 'Economic management'}, {'code': '8', 'name': ''}]
# 420 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '1', 'name': 'Economic management'}]
# 421 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}]
# 422 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': 'Rural development'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '5', 'name': 'Trade and integration'}]
# 423 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '2', 'name': ''}]
# 424 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}]
# 425 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '10', 'name': 'Rural development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 426 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': ''}]
# 427 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 428 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 429 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 430 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '3', 'name': 'Rule of law'}]
# 431 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 432 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '2', 'name': 'Public sector governance'}]
# 433 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': 'Public sector governance'}]
# 434 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 435 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '3', 'name': 'Rule of law'}, {'code': '9', 'name': 'Urban development'}]
# 436 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 437 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 438 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '8', 'name': 'Human development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 439 :"<-key"  [{'code': '3', 'name': 'Rule of law'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 440 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '5', 'name': ''}]
# 441 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 442 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 443 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 444 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 445 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '4', 'name': ''}]
# 446 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]
# 447 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 448 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 449 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '5', 'name': 'Trade and integration'}]
# 450 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '9', 'name': 'Urban development'}, {'code': '8', 'name': 'Human development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 451 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '2', 'name': ''}]
# 452 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}, {'code': '2', 'name': 'Public sector governance'}]
# 453 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '2', 'name': ''}]
# 454 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]
# 455 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}]
# 456 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]
# 457 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '5', 'name': 'Trade and integration'}]
# 458 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 459 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}]
# 460 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '10', 'name': 'Rural development'}]
# 461 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': 'Rural development'}]
# 462 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 463 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '2', 'name': 'Public sector governance'}]
# 464 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '8', 'name': 'Human development'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 465 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 466 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '2', 'name': 'Public sector governance'}]
# 467 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '3', 'name': 'Rule of law'}]
# 468 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}]
# 469 :"<-key"  [{'code': '11', 'name': ''}]
# 470 :"<-key"  [{'code': '5', 'name': 'Trade and integration'}, {'code': '10', 'name': 'Rural development'}]
# 471 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 472 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': ''}]
# 473 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '4', 'name': ''}]
# 474 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '9', 'name': 'Urban development'}]
# 475 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '9', 'name': 'Urban development'}]
# 476 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '8', 'name': ''}]
# 477 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '10', 'name': 'Rural development'}]
# 478 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '3', 'name': 'Rule of law'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 479 :"<-key"  [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '1', 'name': ''}]
# 480 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': ''}]
# 481 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '8', 'name': 'Human development'}]
# 482 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}]
# 483 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 484 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '4', 'name': 'Financial and private sector development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '10', 'name': 'Rural development'}]
# 485 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '4', 'name': ''}]
# 486 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}]
# 487 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': 'Environment and natural resources management'}]
# 488 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}]
# 489 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}, {'code': '9', 'name': 'Urban development'}]
# 490 :"<-key"  [{'code': '2', 'name': 'Public sector governance'}, {'code': '2', 'name': 'Public sector governance'}]
# 491 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '11', 'name': ''}]
# 492 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 493 :"<-key"  [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '5', 'name': ''}]
# 494 :"<-key"  [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '8', 'name': ''}]
# 495 :"<-key"  [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}]
# 496 :"<-key"  [{'code': '8', 'name': 'Human development'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '8', 'name': 'Human development'}]
# 497 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '6', 'name': ''}]
# 498 :"<-key"  [{'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}, {'code': '10', 'name': 'Rural development'}]
# 499 :"<-key"  [{'code': '9', 'name': 'Urban development'}, {'code': '8', 'name': 'Human development'}, {'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}]
# <class 'pandas.core.series.Series'>

# %%
major_theme[11][3]
# Out:
# {'code': '11', 'name': 'Environment and natural resources management'}

# %%
#Load json as a list. 
data2 = json.load(open('data/world_bank_projects.json'))
type(data2)
# Out:
# list

# %%
#I have to normalize this  because 'mjtheme_namecode' is embedded. This makes norm a pandas DataFrame
norm = json_normalize(data2,'mjtheme_namecode',['id'])
print(type(norm))
print(norm)
#each row is made up of a code and name. See below to group by distinct codes/names
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      code                                          name       id
# 0       8                             Human development  P129828
# 1      11                                                P129828
# 2       1                           Economic management  P144674
# 3       6         Social protection and risk management  P144674
# 4       5                         Trade and integration  P145310
# 5       2                      Public sector governance  P145310
# 6      11  Environment and natural resources management  P145310
# 7       6         Social protection and risk management  P145310
# 8       7                   Social dev/gender/inclusion  P144665
# 9       7                   Social dev/gender/inclusion  P144665
# 10      5                         Trade and integration  P144933
# 11      4      Financial and private sector development  P144933
# 12      6         Social protection and risk management  P146161
# 13      6                                                P146161
# 14      2                      Public sector governance  P121185
# 15      4      Financial and private sector development  P121185
# 16     11  Environment and natural resources management  P127033
# 17      8                                                P127033
# 18     10                             Rural development  P130164
# 19      7                                                P130164
# 20      2                      Public sector governance  P130903
# 21      2                      Public sector governance  P130903
# 22      2                      Public sector governance  P130903
# 23     10                             Rural development  P145339
# 24      2                                                P145339
# 25     10                             Rural development  P146653
# 26      6         Social protection and risk management  P146653
# 27      6         Social protection and risk management  P146653
# 28     11  Environment and natural resources management  P146653
# 29      4                                                P144140
# ...   ...                                           ...      ...
# 1469    8                             Human development  P126465
# 1470    9                             Urban development  P128763
# 1471    6         Social protection and risk management  P128763
# 1472    6         Social protection and risk management  P128763
# 1473    9                             Urban development  P128763
# 1474    2                      Public sector governance  P131860
# 1475    2                      Public sector governance  P131860
# 1476   10                             Rural development  P123322
# 1477   11                                                P123322
# 1478    8                             Human development  P128096
# 1479    7                   Social dev/gender/inclusion  P128096
# 1480   11  Environment and natural resources management  P132138
# 1481    5                                                P132138
# 1482    6         Social protection and risk management  P129177
# 1483    8                                                P129177
# 1484    4      Financial and private sector development  P127299
# 1485    7                   Social dev/gender/inclusion  P127299
# 1486    8                             Human development  P125298
# 1487    5                         Trade and integration  P125298
# 1488    2                      Public sector governance  P125298
# 1489    8                             Human development  P125298
# 1490   10                             Rural development  P128309
# 1491    6                                                P128309
# 1492   10                             Rural development  P117243
# 1493   10                             Rural development  P117243
# 1494   10                             Rural development  P117243
# 1495    9                             Urban development  P126321
# 1496    8                             Human development  P126321
# 1497    5                         Trade and integration  P126321
# 1498    4      Financial and private sector development  P126321
#
# [1499 rows x 3 columns]

# %%
#Group by the name of the mjtheme_namecode column
major_theme_names = norm.groupby('code')['name'].unique()
print(major_theme_names)
#You will see 11 distinct codes, and 12 distinct names (this is because the 'name' is blank for the codes at 
#the top of the below list)
# Out:
# code
# 1                              [Economic management, ]
# 10                               [Rural development, ]
# 11    [, Environment and natural resources management]
# 2                         [Public sector governance, ]
# 3                                      [Rule of law, ]
# 4         [Financial and private sector development, ]
# 5                            [Trade and integration, ]
# 6            [Social protection and risk management, ]
# 7                      [Social dev/gender/inclusion, ]
# 8                                [Human development, ]
# 9                                [Urban development, ]
# Name: name, dtype: object

# %%
#c1 = norm.groupby('code')['name'].count()     #this counts the codes, since some codes have a null name, using the below groupby
#would cause the list to miss these distinct codes.
c1 = norm.groupby(norm['code'], as_index=True, sort=True,group_keys=True).size()
#c2 = c1.set_index(['name'])
#from: https://stackoverflow.com/questions/34113203/python-pandas-setting-groupby-group-labels-as-index-in-a-new-dataframe
#c1 = df.groupby(df['Country'], as_index=True, sort=False, group_keys=True).size()
#c1.set_index(['Country'])
c1
#norm.groupby('name')['code'].count()
# Out:
# code
# 1      38
# 10    216
# 11    250
# 2     199
# 3      15
# 4     146
# 5      77
# 6     168
# 7     130
# 8     210
# 9      50
# dtype: int64

# %% [markdown]
# # Answer #2: See above
#
# # Question 3: In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
#norm.groupby('id').code.nunique().sort_values(ascending=False).head(10)
norm.name.value_counts(ascending=False)
# Out:
# Environment and natural resources management    223
# Rural development                               202
# Human development                               197
# Public sector governance                        184
# Social protection and risk management           158
# Financial and private sector development        130
#                                                 122
# Social dev/gender/inclusion                     119
# Trade and integration                            72
# Urban development                                47
# Economic management                              33
# Rule of law                                      12
# Name: name, dtype: int64

# %%
#create lookup table from code to name:
df_themes_name_to_code = norm.groupby('name').code.max().sort_values(ascending=False)

# drop the missing name rows
df_themes_name_to_code = df_themes_name_to_code[df_themes_name_to_code.index != '']

# %%
# convert to df
df_themes_name_to_code = pd.DataFrame(df_themes_name_to_code,columns=['code'])

# pull name into a column
df_themes_name_to_code['name_clean'] = df_themes_name_to_code.index

# set code to be the index
df_themes_code_to_name = df_themes_name_to_code.set_index(['code'])

# %%
print(norm.shape)
df_themes_clean = norm.merge(df_themes_code_to_name,how='outer',left_on=['code'],right_index=True)
print(df_themes_clean.shape)
print(df_themes_clean)
# Out:
# (1499, 3)
# (1499, 4)
#      code               name       id         name_clean
# 0       8  Human development  P129828  Human development
# 17      8                     P127033  Human development
# 41      8  Human development  P132616  Human development
# 43      8  Human development  P146271  Human development
# 44      8  Human development  P146271  Human development
# 47      8  Human development  P146271  Human development
# 57      8  Human development  P146109  Human development
# 58      8  Human development  P146109  Human development
# 69      8  Human development  P143025  Human development
# 79      8  Human development  P122700  Human development
# 91      8  Human development  P145118  Human development
# 113     8  Human development  P128628  Human development
# 117     8                     P098847  Human development
# 120     8  Human development  P125018  Human development
# 146     8  Human development  P132753  Human development
# 147     8  Human development  P132753  Human development
# 148     8  Human development  P132753  Human development
# 186     8  Human development  P131202  Human development
# 190     8  Human development  P126130  Human development
# 191     8  Human development  P126130  Human development
# 192     8  Human development  P126130  Human development
# 206     8  Human development  P126034  Human development
# 228     8  Human development  P131212  Human development
# 229     8  Human development  P131441  Human development
# 237     8  Human development  P144532  Human development
# 238     8  Human development  P144532  Human development
# 239     8  Human development  P123503  Human development
# 240     8                     P123503  Human development
# 245     8  Human development  P120397  Human development
# 278     8  Human development  P143060  Human development
# ...   ...                ...      ...                ...
# 1102    9  Urban development  P130972  Urban development
# 1103    9  Urban development  P130972  Urban development
# 1104    9  Urban development  P130972  Urban development
# 1166    9  Urban development  P101289  Urban development
# 1290    9  Urban development  P118152  Urban development
# 1303    9  Urban development  P130528  Urban development
# 1318    9  Urban development  P130461  Urban development
# 1342    9  Urban development  P130174  Urban development
# 1347    9  Urban development  P131394  Urban development
# 1425    9  Urban development  P112901  Urban development
# 1426    9  Urban development  P112901  Urban development
# 1428    9  Urban development  P118916  Urban development
# 1470    9  Urban development  P128763  Urban development
# 1473    9  Urban development  P128763  Urban development
# 1495    9  Urban development  P126321  Urban development
# 252     3        Rule of law  P128443        Rule of law
# 359     3        Rule of law  P130459        Rule of law
# 415     3        Rule of law  P127787        Rule of law
# 493     3                     P131640        Rule of law
# 508     3        Rule of law  P144386        Rule of law
# 509     3        Rule of law  P144386        Rule of law
# 691     3                     P145095        Rule of law
# 789     3        Rule of law  P121152        Rule of law
# 1029    3                     P129332        Rule of law
# 1209    3        Rule of law  P105269        Rule of law
# 1287    3        Rule of law  P128950        Rule of law
# 1302    3        Rule of law  P130528        Rule of law
# 1316    3        Rule of law  P131767        Rule of law
# 1411    3        Rule of law  P125202        Rule of law
# 1434    3        Rule of law  P131266        Rule of law
#
# [1499 rows x 4 columns]

# %%
#create function that can drop in correct names for normalized json column 'mjtheme_namecode
def clean_mjtheme(value):
    for name in value:
        if len(name[0]) < 1:
            name[1]
        else:
            name[0]
    return value

output = clean_mjtheme(norm) 
output
# Out:
#      code                                          name
# 0       8                             Human development
# 1      11
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# 16     11  Environment and natural resources management
# 17      8
# 18     10                             Rural development
# 19      7
# 20      2                      Public sector governance
# 21      2                      Public sector governance
# 22      2                      Public sector governance
# 23     10                             Rural development
# 24      2
# 25     10                             Rural development
# 26      6         Social protection and risk management
# 27      6         Social protection and risk management
# 28     11  Environment and natural resources management
# 29      4
# ...   ...                                           ...
# 1469    8                             Human development
# 1470    9                             Urban development
# 1471    6         Social protection and risk management
# 1472    6         Social protection and risk management
# 1473    9                             Urban development
# 1474    2                      Public sector governance
# 1475    2                      Public sector governance
# 1476   10                             Rural development
# 1477   11
# 1478    8                             Human development
# 1479    7                   Social dev/gender/inclusion
# 1480   11  Environment and natural resources management
# 1481    5
# 1482    6         Social protection and risk management
# 1483    8
# 1484    4      Financial and private sector development
# 1485    7                   Social dev/gender/inclusion
# 1486    8                             Human development
# 1487    5                         Trade and integration
# 1488    2                      Public sector governance
# 1489    8                             Human development
# 1490   10                             Rural development
# 1491    6
# 1492   10                             Rural development
# 1493   10                             Rural development
# 1494   10                             Rural development
# 1495    9                             Urban development
# 1496    8                             Human development
# 1497    5                         Trade and integration
# 1498    4      Financial and private sector development
#
# [1499 rows x 2 columns]

# %%
#replace '' with the 'name' value associated with the correct 'code'. See here for functions with lambda and the .apply method:
#https://campus.datacamp.com/courses/cleaning-data-in-python/cleaning-data-for-analysis?ex=10 
#df['mjtheme_namecode'].apply(lambda x)
def filled_name(value):
    for clean in value:
        print([{'code': clean['code'], 
                'name' : output.loc[clean['code']]}])      # clean_mjtheme.loc(norm)
        return value
filled_name(output)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Andrew\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1410                 if key not in ax:
# -> 1411                     error()
#    1412             except TypeError as e:
#
# C:\Users\Andrew\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1405                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1406                                (key, self.obj._get_axis_name(axis)))
#    1407
#
# KeyError: 'the label [c] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-8415d69e8aa1> in <module>()
#      16                 'name' : output.loc[clean[0]]}])      # clean_mjtheme.loc(norm)
#      17         return value
# ---> 18 filled_name(output)
#
# <ipython-input-101-8415d69e8aa1> in filled_name(value)
#      14     for clean in value:
#      15         print([{'code': clean[0],
# ---> 16                 'name' : output.loc[clean[0]]}])      # clean_mjtheme.loc(norm)
#      17         return value
#      18 filled_name(output)
#
# C:\Users\Andrew\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# C:\Users\Andrew\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1480
#    1481         # fall thru to straight lookup
# -> 1482         self._has_valid_type(key, axis)
#    1483         return self._get_label(key, axis=axis)
#    1484
#
# C:\Users\Andrew\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1417                 raise
#    1418             except:
# -> 1419                 error()
#    1420
#    1421         return True
#
# C:\Users\Andrew\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1404                                     "key")
#    1405                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1406                                (key, self.obj._get_axis_name(axis)))
#    1407
#    1408             try:
#
# KeyError: 'the label [c] is not in the [index]'
